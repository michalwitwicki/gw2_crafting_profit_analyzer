# %%
import pandas as pd 
df = pd.read_json("database/crafting_profit.json")
df = df.convert_dtypes()
# df.dtypes

# %%
df = df[df['disciplines_str'].str.contains("Chef|Armorsmith")]

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
	display(df[[	
		'item_name',
		'sell_price',
		'crafting_price',

		'crafting_profit',
		'crf_prf_estimate',
		'crafting_roi',

		# 'crafting_profit_INS',
		# 'crafting_roi_INS',

		'7d_sell_sold',
		'1d_sell_sold',
		'7d_SL_diff',
		'1d_SL_diff',
		'1d_5%_SS',
		'disciplines',
		'difficult'
		]]

	.loc	[
		(df['crafting_profit'] > 1) &
		(df['crafting_profit'] > df['flip_profit']) &
		# (df['difficult'] == False) &

		# (df['1d_SL_diff'] > -10) &
		(df['7d_SL_diff'] > -10) &
		(df['1d_sell_sold'] > 1) &
		(df['7d_sell_sold'] > 1) 
		]

	.sort_values(by='crafting_profit', ascending=False)
	# .sort_values(by='crf_prf_estimate', ascending=False)
	# .sort_values(by='crafting_profit_INS', ascending=False)
	# .sort_values(by='1d_sell_sold', ascending=False)

	.style.hide_index()
	# .head(20)
	# .shape[0]
	)
# Out:
# <style  type="text/css" >
# </style><table id="T_c704e_" ><thead>    <tr>        <th class="col_heading level0 col0" >item_name</th>        <th class="col_heading level0 col1" >sell_price</th>        <th class="col_heading level0 col2" >crafting_price</th>        <th class="col_heading level0 col3" >crafting_profit</th>        <th class="col_heading level0 col4" >crf_prf_estimate</th>        <th class="col_heading level0 col5" >crafting_roi</th>        <th class="col_heading level0 col6" >7d_sell_sold</th>        <th class="col_heading level0 col7" >1d_sell_sold</th>        <th class="col_heading level0 col8" >7d_SL_diff</th>        <th class="col_heading level0 col9" >1d_SL_diff</th>        <th class="col_heading level0 col10" >1d_5%_SS</th>        <th class="col_heading level0 col11" >disciplines</th>        <th class="col_heading level0 col12" >difficult</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c704e_row0_col0" class="data row0 col0" >Berserker's Draconic Legs</td>
#                         <td id="T_c704e_row0_col1" class="data row0 col1" >88990</td>
#                         <td id="T_c704e_row0_col2" class="data row0 col2" >62193</td>
#                         <td id="T_c704e_row0_col3" class="data row0 col3" >13448</td>
#                         <td id="T_c704e_row0_col4" class="data row0 col4" >13448</td>
#                         <td id="T_c704e_row0_col5" class="data row0 col5" >22</td>
#                         <td id="T_c704e_row0_col6" class="data row0 col6" >160</td>
#                         <td id="T_c704e_row0_col7" class="data row0 col7" >28</td>
#                         <td id="T_c704e_row0_col8" class="data row0 col8" >53</td>
#                         <td id="T_c704e_row0_col9" class="data row0 col9" >14</td>
#                         <td id="T_c704e_row0_col10" class="data row0 col10" >1</td>
#                         <td id="T_c704e_row0_col11" class="data row0 col11" >['Armorsmith']</td>
#                         <td id="T_c704e_row0_col12" class="data row0 col12" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_c704e_row1_col0" class="data row1 col0" >Berserker's Draconic Boots</td>
#                         <td id="T_c704e_row1_col1" class="data row1 col1" >88280</td>
#                         <td id="T_c704e_row1_col2" class="data row1 col2" >61708</td>
#                         <td id="T_c704e_row1_col3" class="data row1 col3" >13330</td>
#                         <td id="T_c704e_row1_col4" class="data row1 col4" >13330</td>
#                         <td id="T_c704e_row1_col5" class="data row1 col5" >22</td>
#                         <td id="T_c704e_row1_col6" class="data row1 col6" >145</td>
#                         <td id="T_c704e_row1_col7" class="data row1 col7" >21</td>
#                         <td id="T_c704e_row1_col8" class="data row1 col8" >15</td>
#                         <td id="T_c704e_row1_col9" class="data row1 col9" >1</td>
#                         <td id="T_c704e_row1_col10" class="data row1 col10" >1</td>
#                         <td id="T_c704e_row1_col11" class="data row1 col11" >['Armorsmith']</td>
#                         <td id="T_c704e_row1_col12" class="data row1 col12" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_c704e_row2_col0" class="data row2 col0" >Knight's Gladiator Boots</td>
#                         <td id="T_c704e_row2_col1" class="data row2 col1" >14895</td>
#                         <td id="T_c704e_row2_col2" class="data row2 col2" >2311</td>
#                         <td id="T_c704e_row2_col3" class="data row2 col3" >10349</td>
#                         <td id="T_c704e_row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_c704e_row2_col5" class="data row2 col5" >448</td>
#                         <td id="T_c704e_row2_col6" class="data row2 col6" >14</td>
#                         <td id="T_c704e_row2_col7" class="data row2 col7" >11</td>
#                         <td id="T_c704e_row2_col8" class="data row2 col8" >8</td>
#                         <td id="T_c704e_row2_col9" class="data row2 col9" >9</td>
#                         <td id="T_c704e_row2_col10" class="data row2 col10" >0</td>
#                         <td id="T_c704e_row2_col11" class="data row2 col11" >['Armorsmith']</td>
#                         <td id="T_c704e_row2_col12" class="data row2 col12" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_c704e_row3_col0" class="data row3 col0" >Berserker's Gladiator Pauldrons</td>
#                         <td id="T_c704e_row3_col1" class="data row3 col1" >17474</td>
#                         <td id="T_c704e_row3_col2" class="data row3 col2" >4629</td>
#                         <td id="T_c704e_row3_col3" class="data row3 col3" >10224</td>
#                         <td id="T_c704e_row3_col4" class="data row3 col4" >0</td>
#                         <td id="T_c704e_row3_col5" class="data row3 col5" >221</td>
#                         <td id="T_c704e_row3_col6" class="data row3 col6" >20</td>
#                         <td id="T_c704e_row3_col7" class="data row3 col7" >13</td>
#                         <td id="T_c704e_row3_col8" class="data row3 col8" >13</td>
#                         <td id="T_c704e_row3_col9" class="data row3 col9" >10</td>
#                         <td id="T_c704e_row3_col10" class="data row3 col10" >0</td>
#                         <td id="T_c704e_row3_col11" class="data row3 col11" >['Armorsmith']</td>
#                         <td id="T_c704e_row3_col12" class="data row3 col12" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_c704e_row4_col0" class="data row4 col0" >Carrion Gladiator Gauntlets</td>
#                         <td id="T_c704e_row4_col1" class="data row4 col1" >14999</td>
#                         <td id="T_c704e_row4_col2" class="data row4 col2" >3136</td>
#                         <td id="T_c704e_row4_col3" class="data row4 col3" >9613</td>
#                         <td id="T_c704e_row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_c704e_row4_col5" class="data row4 col5" >307</td>
#                         <td id="T_c704e_row4_col6" class="data row4 col6" >16</td>
#                         <td id="T_c704e_row4_col7" class="data row4 col7" >12</td>
#                         <td id="T_c704e_row4_col8" class="data row4 col8" >8</td>
#                         <td id="T_c704e_row4_col9" class="data row4 col9" >4</td>
#                         <td id="T_c704e_row4_col10" class="data row4 col10" >0</td>
#                         <td id="T_c704e_row4_col11" class="data row4 col11" >['Armorsmith']</td>
#                         <td id="T_c704e_row4_col12" class="data row4 col12" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_c704e_row5_col0" class="data row5 col0" >Honed Gladiator Chestplate</td>
#                         <td id="T_c704e_row5_col1" class="data row5 col1" >14785</td>
#                         <td id="T_c704e_row5_col2" class="data row5 col2" >3286</td>
#                         <td id="T_c704e_row5_col3" class="data row5 col3" >9282</td>
#                         <td id="T_c704e_row5_col4" class="data row5 col4" >0</td>
#                         <td id="T_c704e_row5_col5" class="data row5 col5" >282</td>
#                         <td id="T_c704e_row5_col6" class="data row5 col6" >16</td>
#                         <td id="T_c704e_row5_col7" class="data row5 col7" >2</td>
#                         <td id="T_c704e_row5_col8" class="data row5 col8" >15</td>
#                         <td id="T_c704e_row5_col9" class="data row5 col9" >2</td>
#                         <td id="T_c704e_row5_col10" class="data row5 col10" >0</td>
#                         <td id="T_c704e_row5_col11" class="data row5 col11" >['Armorsmith']</td>
#                         <td id="T_c704e_row5_col12" class="data row5 col12" >False</td>
#             </tr>
#             <tr>
#                                 <t

# %% [markdown]
# ## What am I currently crafting ##
# - 5x Mystic Aspect
#
# ## What am I currently crafting for instant sell ##
#
# ## What I was crafting for instant sell ##
# - 300x Cup of Light-Roasted Coffee
#
# ## What I was crafting for instant sell ##
# - Cleric's Gladiator Gauntlets
